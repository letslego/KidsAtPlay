# %%
# %matplotlib inline
# General imports
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
import random
from collections import Counter, defaultdict
from operator import itemgetter
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/Slow_Kids_Data_Collection.csv')

# %%
df.shape
df.head(10)
# Out:
#    Speed Direction  Treatment  SameSide  Children  Pedestrians  Hour  \
# 0     26         s          0         1         0            0  1400
# 1     30         s          0         1         0            0  1400
# 2     27         s          0         1         0            0  1400
# 3     31         n          0         0         0            0  1400
# 4     26         n          0         0         0            0  1400
# 5     26         n          0         0         0            0  1400
# 6     28         s          0         1         0            0  1400
# 7     35         n          0         0         0            0  1400
# 8     33         n          0         0         0            0  1400
# 9     25         s          0         1         0            0  1400
#
#   Visibility Location      Date  DayofWeek Observer  ReformattedDate CityID  \
# 0      Clear        A  7/1/2017          7    Scott              701     OR
# 1      Clear        A  7/1/2017          7    Scott              701     OR
# 2      Clear        A  7/1/2017          7    Scott              701     OR
# 3      Clear        A  7/1/2017          7    Scott              701     OR
# 4      Clear        A  7/1/2017          7    Scott              701     OR
# 5      Clear        A  7/1/2017          7    Scott              701     OR
# 6      Clear        A  7/1/2017          7    Scott              701     OR
# 7      Clear        A  7/1/2017          7    Scott              701     OR
# 8      Clear        A  7/1/2017          7    Scott              701     OR
# 9      Clear        A  7/1/2017          7    Scott              701     OR
#
#             Cluster
# 0  OR-A-0701-1400-0
# 1  OR-A-0701-1400-0
# 2  OR-A-0701-1400-0
# 3  OR-A-0701-1400-0
# 4  OR-A-0701-1400-0
# 5  OR-A-0701-1400-0
# 6  OR-A-0701-1400-0
# 7  OR-A-0701-1400-0
# 8  OR-A-0701-1400-0
# 9  OR-A-0701-1400-0

# %%
model = smf.ols('Speed ~ Treatment + SameSide + Children + Pedestrians + DayofWeek', data=df)
results = model.fit(cov_type='cluster',cov_kwds={'groups':df.Cluster})
print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Speed   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     36.22
# Date:                Sun, 13 Aug 2017   Prob (F-statistic):           4.69e-12
# Time:                        14:56:15   Log-Likelihood:                -1964.6
# No. Observations:                 699   AIC:                             3941.
# Df Residuals:                     693   BIC:                             3968.
# Df Model:                           5
# Covariance Type:              cluster
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept      28.6332      0.391     73.186      0.000        27.866    29.400
# Treatment      -1.5736      0.405     -3.885      0.000        -2.368    -0.780
# SameSide       -0.3052      0.454     -0.672      0.502        -1.196     0.585
# Children       -4.0999      0.594     -6.906      0.000        -5.263    -2.936
# Pedestrians    -1.3495      0.529     -2.552      0.011        -2.386    -0.313
# DayofWeek      -0.0697      0.078     -0.895      0.371        -0.222     0.083
# ==============================================================================
# Omnibus:                       26.736   Durbin-Watson:                   1.748
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.893
# Skew:                           0.345   Prob(JB):                     5.91e-09
# Kurtosis:                       3.908   Cond. No.                         46.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
